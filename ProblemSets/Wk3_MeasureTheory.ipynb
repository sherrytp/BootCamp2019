# %% [markdown]
# ## Math, Problem Set 1 - Measure Theory
#
#
# * SP Tian
# * Monday, July 22, 2019
#
#
# > Exercises from Measure Theory notes.
#
#
# * • 1.3, 1.7, 1.10, 1.22, 1.23, 1.26,
# * • 2.10, 2.14,
# * • 3.1, 3.7, 3.10, 3.17,
# * • 4.13, 4.14, 4.15, 4.16, 4.21

# %% [markdown]
# 1. Measure Spaces
#
# 1.3.1
#
# $\mathcal{G}1$ isn't an algebra. Since for $\forall A \in \mathcal{G}1$, $A$ is open, and then $A^c$ is closed in $\mathbb{R}$; $A$ $\notin \mathbb{R}$.
#
# 1.3.2
#
# $\mathcal{G}2$ is an algebra. $\mathcal{G}2$ is not a $\sigma$-algebra.
#
# 1.3.3
#
# $\mathcal{G}3$ is a $\sigma$-algebra; therefore, an algebra.

# %% [markdown]
# 1.7
# **Proof**: if $A$ is any $\sigma$-algebra, then $\{\emptyset, X\} \subset A \subset \mathcal{P}(X)$.
#
# Since $\forall \sigma-algebra$, $\emptyset \in A$; also, $X = (\emptyset)^c$; therfore, $\forall \sigma-algebra, X \subset A$. In conclusion, $\{\emptyset, X\} \subset A$.
#
# Secondly, because $\mathbb{B}$-$\sigma$-algebra is the smallest $\sigma$-algebra that contains all open sets of $X$, $P(X) = \{A: A \subset X \}$. For $\forall \sigma$-algebra $\mathcal{A}$, $\forall A \in \mathcal{A}, A \subset X$. So $A \subset \mathcal{P}(X)$.

# %% [markdown]
# 1.10 **Proof**: $\cap_a \mathcal{S}_a$ is a $\sigma$-algebra.
#
# Let $F = \cap_a\mathcal{S}_a$, then for $\forall \alpha$ if $A \in F \rightarrow A \in \mathcal{S}_a$. For $ \forall \alpha$, $\cup_{n=1} A_n \in \mathcal{S}_a \rightarrow \cap_{n=1} A_n \in F$; therefore, it's a $\sigma$-algebra.

# %% [markdown]
# 1.22.1
# **Proof**: If $A, B \in \mathcal{S}$ and $A \subset B$, $\mu$ is the measurable space in $(X, \mathcal{S})$ space. Then $\mu(A) \leq \mu(B)$, meaning $\mu$ is monotone.
#
# 1.22.2
# **Proof**: If $\{A_i\}^{\infty}_{i=1} \subset \mathcal{A}$, so the smallest $\sigma$-algebra $\mu(\cup^{\infty}_{i=1}$ is countable and smaller or equal to $\sum^{\infty}_{i=1} \mu(A_i)$.

# %% [markdown]
# 1.23
#
# $\lambda(\theta) = \mu(\theta \cap B) = \mu(\theta) = 0$  Therefore, since $A_i$ are disjoint sets, $\lambda(\cup^\infty_{i=1}A_i) = \mu(\cup^\infty_{i=1}A_i\cap B) = \mu((\cup^\infty_{i=1}A_i)\cap B) = \mu(\cup^\infty_{i=1}(A_i\cap B)) = \Sigma^\infty_{i=1} \mu(A_i)\cap B) = \Sigma^\infty_{i=1} \lambda(A_i\cap B)$

# %% [markdown]
# 2.10 **Proof**:
#
# Since $B = (B \cap E) \cup (B \cup E^c)$ and $\mu^*$ is an outer measure, so $\mu$ is countably sub-additive. $\mu^*((B \cap E) \cup (B \cap E^c)) \leq \mu^*(B \cap E) + \mu*(B \cap E^c)$; in result, $\mu^*(B) \leq \mu*(B \cap E) + \mu^*(B \cap E^*)$. With reference to Theorem 2.8, we obtain $\mu^*(B) \geq \mu^*(B \cap E) + \mu^*(B \cap E^c)$.

# %% [markdown]
# 2.14 **Proof**: Borel-algebra $\mathcal{B}(\mathbb{R})$ is a subset of $\mathcal(M)$?
#
# Def $\mathcal{O} = \{A: A is open, A \subset \mathbb{R}\}$, $v$ is a premeasure on $\mathbb{R}$, denote $\mu^*$ as the outer measure by $v$. Then $\sigma(\mathcal{O}$ is the $\sigma$-algebra generated by $\mathcal{O}$ and $\mathcal{M}$ as the $\sigma$-algebra from Carátheodory construction. With reference to 2.12, we obtain $\mathcal{o}(\mathcal{O}) \subset \mathcal{M}$. Since $\sigma$-algebra is generated by $\mathcal{O}$, it is the Borel-algebra, $\mathcal{B}(\mathbb{R}) \subset \mathcal{M}$.

# %% [markdown]
# 3.1 **Proof**:
#
# Let $A$ be the countable subset of the real line; then for each $a_n \in A$, define the Lebesgue Measure, so we have $m(I_n) =
# \dfrac{2\sigma}{2^{n+1}}$, which makes $\sigma$ small each to validate the proof.

# %% [markdown]
# 3.7.1 **Proof**:
#
# Since $f^{-1}([a,\infty)) = f^{-1}((-\infty,a))^c$ and $\mathcal{M}$ is closed under complements, $f^{-1}([a,\infty])\in \mathcal{M}$.
#
# 3.7.2 **Proof**:
#
# Since $f^{-1}((a,\infty)) = \cap^\infty_{i=1}f^{-1}([\dfrac{a-1}{n}, \infty))$ and $\mathcal{M}$ is closed under countable intersections, $f^{-1}([a,\infty])\in \mathcal{M}$.
#
# 3.7.3 **Proof**:
#
# Since $f^{-1}((-\infty,a]) = f^{-1}((a,\infty))^c$ and $\mathcal{M}$ is closed under complements, $f^{-1}([a,\infty])\in \mathcal{M}$.

# %% [markdown]
# 3.10
#
# * Let $F(f(x),g(x)) = f(x) + g(x)$. The function is continuous and measuable, so $f + g$ should be measurable.
# * Let $F(f(x),g(x)) = f(x) * g(x)$. The function is continuous and measurable, so $f*g$ shoudl be measurable.
# * Note that {$x \in X: \max(f(x),g(x)) < y$} = {$x \in X: f(x) < y$} $\cap$ {$x \in X: g(x) < y$}. Since f and g are measuable, $F = \max(f(x),g(x))$ is measurable.
# * Same for {$x \in X: \min(f(x),g(x)) > y$} = {$x \in X: f(x) > y$} $\cap$ {$x \in X: g(x) > y$}. Since f and g are measuable, $F = \min(f(x),g(x))$ is measurable.

# %% [markdown]
# 3.17
#
# Since the uniform convergence for $\epsilon > 0$, when $f$ is bounded, the $\mathcal{B}$ satisfying such that $|f(x)| < \mathcal{B}, \forall x$. In the case, a number can be found big enough for $||s_n(x) - f(x)|| < \epsilon$.

# %% [markdown]
# 4.13
#
# Since $|f| < M$ on $E$, then $0\leq f- < M$, and $0 \leq f+ < M$. Using $\mu(E) < \infty$, concluding that $\int_Ef-d\mu < M\mu(E) < \infty$ and $\int_Ef+d\mu < M\mu(E) < \infty$; thus, $f \in \mathcal{L^1}(\mu, E)$.

# %% [markdown]
# 4.14
#
# Contra-positive: suppose there exists a measurable set $E'\subset E$ such that function $f$ is infinite on $E'$. Without loss of generality, assumption is $f = \infty$. Then the contradiction $f \notin \mathcal{L}(\mu, E)$ could be drawn from $\infty = \int_{E'}fd\mu \leq \infty_Efd\mu \leq \int_E||f||d\mu$.

# %% [markdown]
# 4.15
#
# Define the following the functions $B(f) = ${$s : 0\leq s\leq f, s$ simple and measurable}. Without loss of generality, suppose $f\leq g$. Then, $f+ \leq g+$ and $f- \geq g-$. In the case $B(f+) \subset B(g+)$ and $B(g-) \subset B(f-)$, implying that $\int_Efd\mu = \int f+d\mu - \int_E f-d\mu \leq \int_E g+d\mu - \int_E g-d\mu = \int_E gd\mu$.

# %% [markdown]
# 4.16
#
# $f\in \mathcal{L^1}(E,\mu)$ implies that $\int_E f+d\mu < \infty$ and $\int_E f-d\mu < \infty$. $A \subset E$ tells us that $\int_A f+d\mu < \infty$ and $\int_A f-d\mu < \infty$. In conclusion, $f \in \mathcal{L^1}(A,\mu)$.

# %% [markdown]
# 4.21
#
# Since $\int_{A-B}fd\mu = 0$ and $f\in \mathcal{L^1}$, applying Theorem 4.19 gives us that $\int_A f+d\mu$ and $\int_A f-d\mu$ are measuable on $\mathcal{M}$. Usng the definition of Lesbesque integral, $\int_A fd\mu = \int_A f+ d\mu - \int_A f- d\mu$. With reference to $A = (\dfrac{A}{B})\cup (A\cap B) = \dfrac{A}{B}\cup B$. Using $\mu(A-B) = 0$, we infer that $\int_A fd\mu = \int_{\dfrac{A}{B}}fd\mu + \int_B fd\mu = \int_B fd\mu$.
